# %% [markdown]
# # Ecommerce Sales Insight

# %% [markdown]
# ### Import Libraies

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read CSV

# %%
df = pd.read_csv("e_com data.csv")
df
# Out:
#      OrderID  CustomerName     Category   Product  Quantity  Price  Discount  \
# 0       1001  Anjali Yadav    Groceries  Rice Bag         1   2175      15.0
# 1       1002    Neha Singh  Electronics     Chair         1    813      20.0
# 2       1003   Rajesh Sahu  Electronics  Textbook         5   1162      20.0
# 3       1004  Vikash Gupta    Furniture  Rice Bag         3   2076       5.0
# 4       1005  Anjali Yadav    Groceries    Laptop         1   1396       0.0
# ..       ...           ...          ...       ...       ...    ...       ...
# 195     1196   Rajesh Sahu        Books     Shirt         2   1739      15.0
# 196     1197           NaN    Groceries     Jeans         3    927       5.0
# 197     1198    Neha Singh    Furniture  Textbook         3   2830       5.0
# 198     1199  Priya Sharma     Clothing    Mobile         1   3631      15.0
# 199     1200   Sonal Mehta    Groceries  Textbook         5   4551      10.0
#
#       OrderDate       City  PaymentMode
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       200 non-null    int64
#  1   CustomerName  190 non-null    object
#  2   Category      200 non-null    object
#  3   Product       200 non-null    object
#  4   Quantity      200 non-null    int64
#  5   Price         200 non-null    int64
#  6   Discount      190 non-null    float64
#  7   OrderDate     200 non-null    object
#  8   City          190 non-null    object
#  9   PaymentMode   200 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 15.8+ KB

# %%
df.head()
# Out:
#    OrderID  CustomerName     Category   Product  Quantity  Price  Discount  \
# 0     1001  Anjali Yadav    Groceries  Rice Bag         1   2175      15.0
# 1     1002    Neha Singh  Electronics     Chair         1    813      20.0
# 2     1003   Rajesh Sahu  Electronics  Textbook         5   1162      20.0
# 3     1004  Vikash Gupta    Furniture  Rice Bag         3   2076       5.0
# 4     1005  Anjali Yadav    Groceries    Laptop         1   1396       0.0
#
#     OrderDate       City  PaymentMode
# 0  01-01-2024      Delhi         card
# 1  02-01-2024  Bangalore         card
# 2  03-01-2024    Kolkata  Credit Card
# 3  04-01-2024    Chennai         CASH
# 4  05-01-2024        NaN          upi

# %%
df.tail()
# Out:
#      OrderID  CustomerName   Category   Product  Quantity  Price  Discount  \
# 195     1196   Rajesh Sahu      Books     Shirt         2   1739      15.0
# 196     1197           NaN  Groceries     Jeans         3    927       5.0
# 197     1198    Neha Singh  Furniture  Textbook         3   2830       5.0
# 198     1199  Priya Sharma   Clothing    Mobile         1   3631      15.0
# 199     1200   Sonal Mehta  Groceries  Textbook         5   4551      10.0
#
#       OrderDate       City  PaymentMode
# 195  14-07-2024    Chennai          UPI
# 196  15-07-2024    Kolkata          UPI
# 197  16-07-2024  Hyderabad         Cash
# 198  17-07-2024    Kolkata  Credit Card
# 199  18-07-2024  Bangalore         CASH

# %%
df.desctribe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10564\3061320838.py in ?()
# ----> 1 df.desctribe
#
# C:\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'desctribe'
